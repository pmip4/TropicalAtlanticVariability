# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
sns.set_theme(style="whitegrid")

# %%
# Load all the data
all_runs = pd.read_csv("summary_data/tidy_numbers.csv")
# Jump through some hoops to remove suspect data...
numerical=all_runs.iloc[:,2:]
numerical.mask(abs(numerical) > 1e8, np.nan,inplace=True)
#numerical.mask(abs(numerical) < 1e-6, np.nan,inplace=True)
all_runs.iloc[:,2:]=numerical

# %%
lgm=all_runs.loc[all_runs['experiment'] == 'lgm-cal-adj']
lgm.set_index('model', inplace = True)
lgm['experiment']='lgm'
lgm['ensemble']='lgm'
lgm['run']='expt'
all_pis=all_runs.loc[all_runs['experiment'] == 'piControl']
all_pis.set_index('model', inplace = True)
lgm_pis=all_pis[all_pis.index.isin(lgm.index)]
lgm_pis['ensemble']='lgm'
lgm_pis['run']='ctl'

# %%
midHolocene=all_runs.loc[all_runs['experiment'] == 'midHolocene-cal-adj']
midHolocene.set_index('model', inplace = True)
midHolocene['experiment']='midHolocene'
midHolocene['ensemble']='midHolocene'
midHolocene['run']='expt'
midHolocene_pis=all_pis[all_pis.index.isin(midHolocene.index)]
midHolocene_pis['ensemble']='midHolocene'
midHolocene_pis['run']='ctl'

# %%
lig127k=all_runs.loc[all_runs['experiment'] == 'lig127k-cal-adj']
lig127k.set_index('model', inplace = True)
lig127k['experiment']='lig127k'
lig127k['ensemble']='lig127k'
lig127k['run']='expt'
lig127k_pis=all_pis[all_pis.index.isin(lig127k.index)]
lig127k_pis['ensemble']='lig127k'
lig127k_pis['run']='ctl'

# %%
abrupt4xCO2=all_runs.loc[all_runs['experiment'] == 'abrupt4xCO2']
abrupt4xCO2.set_index('model', inplace = True)
abrupt4xCO2['ensemble']='abrupt4xCO2'
abrupt4xCO2['run']='expt'
abrupt4xCO2_pis=all_pis[all_pis.index.isin(abrupt4xCO2.index)]
abrupt4xCO2_pis['ensemble']='abrupt4xCO2'
abrupt4xCO2_pis['run']='ctl'

# %%
midPliocene=all_runs.loc[all_runs['experiment'] == 'midPliocene-eoi400']
midPliocene.set_index('model', inplace = True)
midPliocene['experiment']='midPliocene'
midPliocene['ensemble']='midPliocene'
midPliocene['run']='expt'
midPliocene_pis=all_pis[all_pis.index.isin(midPliocene.index)]
midPliocene_pis['ensemble']='midPliocene'
midPliocene_pis['run']='ctl'
midPliocene
# Out:
#                   experiment  years   GMTemp  ATL3 mean  ATL3 stddev  \
# model
# CESM2            midPliocene   1200  19.0015    31.5208     0.422629
# EC-Earth3-LR     midPliocene    100  18.1468    29.9173     0.372802
# GISS-E2-1-G      midPliocene    100  15.8968    29.2113     0.372412
# HadGEM3-GC31-LL  midPliocene    100  18.9683    31.0700     0.440798
# IPSL-CM6A-LR     midPliocene    200  15.9784    28.1071     0.380582
# NorESM1-F        midPliocene    200  16.2346    28.8221     0.423445
# UofT-CCSM-4      midPliocene    100  16.7930    29.3439     0.339782
#
#                  Nino34 stddev  AtlNino mean  AtlNino stddev  AMM AnnCycAmp  \
# model
# CESM2                 1.186400       31.5208        0.475870        6.75320
# EC-Earth3-LR          0.360539       29.9173        0.375170        8.56820
# GISS-E2-1-G           1.200440       29.2113        0.373429        6.43383
# HadGEM3-GC31-LL       0.711871       31.0700        0.444555        7.10570
# IPSL-CM6A-LR          1.000140       28.1071        0.380845        8.45978
# NorESM1-F             0.415733       28.8221        0.423535        6.51965
# UofT-CCSM-4           0.515634       29.3439        0.342221        6.19804
#
#                  AMM mean  ...  ATL3 Period  ENSO Period  AMM Period  \
# model                      ...
# CESM2            1.480600  ...      3.98671      3.60360     7.14286
# EC-Earth3-LR     0.013943  ...      2.38095      7.69231     7.69231
# GISS-E2-1-G     -0.147550  ...      4.76190      4.76190     4.34783
# HadGEM3-GC31-LL  0.619316  ...      4.76190      5.00000     5.00000
# IPSL-CM6A-LR     0.145058  ...      2.85714      3.44828     4.44444
# NorESM1-F       -0.088276  ...      7.14286      6.06061     7.40741
# UofT-CCSM-4      0.031926  ...      5.00000      4.76190     7.69231
#
#                  ATL3-sst-interann-stdev  ATL3-pr-interann-stdev  \
# model
# CESM2                           0.325210                0.745376
# EC-Earth3-LR                    0.234637                0.592902
# GISS-E2-1-G                     0.291006                0.821803
# HadGEM3-GC31-LL                 0.332664                1.427230
# IPSL-CM6A-LR                    0.245657                0.632286
# NorESM1-F                       0.311025                1.134200
# UofT-CCSM-4                     0.242977                0.582021
#
#                  ATL3-sst-interjja-stdev  ATL3-pr-interjja-stdev  r(atl3.amo)  \
# model
# CESM2                           0.460426                1.408220    -0.381411
# EC-Earth3-LR                    0.367237                1.578110    -0.053395
# GISS-E2-1-G                     0.368300                1.679030    -0.041824
# HadGEM3-GC31-LL                 0.564919                1.455950    -0.245004
# IPSL-CM6A-LR                    0.471730                0.670945     0.042280
# NorESM1-F                       0.660106                2.629880    -0.078027
# UofT-CCSM-4                     0.396314                1.631930    -0.177942
#
#                     ensemble   run
# model
# CESM2            midPliocene  expt
# EC-Earth3-LR     midPliocene  expt
# GISS-E2-1-G      midPliocene  expt
# HadGEM3-GC31-LL  midPliocene  expt
# IPSL-CM6A-LR     midPliocene  expt
# NorESM1-F        midPliocene  expt
# UofT-CCSM-4      midPliocene  expt
#
# [7 rows x 31 columns]

# %%
# Combine altogether
all_ensembles=pd.concat([midHolocene,midHolocene_pis,lig127k,lig127k_pis,midPliocene,midPliocene_pis,abrupt4xCO2,abrupt4xCO2_pis],ignore_index=True)

# %%
fig=plt.figure()
palette={"piControl": "black", 'midPliocene':'tab:pink',
                             'midHolocene':'tab:olive',
                             'lig127k':'tab:green',
                             'abrupt4xCO2':'tab:red'}
ax=fig.add_subplot(111)
ax=sns.violinplot(data=all_ensembles, x="ensemble", y="ATL3 stddev", hue="run",
               split=True, inner="quart", linewidth=1,palette={'ctl':'gray','expt':'gainsboro'})
ax=sns.swarmplot(x="ensemble", y="ATL3 stddev", hue="experiment",
                   data=all_ensembles,palette=palette,dodge=True)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=4, fancybox=True, shadow=True)
plt.ylim(0,1)
fig.savefig('plots/ATL3_violin_raw.pdf')

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax=sns.violinplot(data=all_ensembles, x="ensemble", y="Nino34 stddev", hue="run",
               split=True, inner="quart", linewidth=1,palette={'ctl':'gray','expt':'gainsboro'})
ax=sns.swarmplot(x="ensemble", y="Nino34 stddev", hue="experiment",
                   data=all_ensembles,palette=palette,dodge=True)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=4, fancybox=True, shadow=True)
plt.ylim(0,2)
fig.savefig('plots/Nino34_violin_raw.pdf')
